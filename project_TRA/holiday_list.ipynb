# %%
import pandas as pd

# %%
df_holiday = pd.read_excel( '歷年連假天數.xlsx' )

# %%
df_holiday
# Out:
#     Unnamed: 0   春節   端午   中秋   雙十  二二八   元旦   清明   勞動  Unnamed: 9       春節.1  \
# 0       2005.0  6.0  3.0  3.0  3.0  3.0  3.0  4.0  2.0         NaN   2/8-2/13
# 1       2006.0  6.0  1.0  3.0  1.0  1.0  2.0  1.0  3.0         NaN   1/28-2/2
# 2       2007.0  9.0  4.0  4.0  1.0  1.0  3.0  4.0  1.0         NaN  2/17-2/25
# 3       2008.0  6.0  2.0  2.0  3.0  1.0  1.0  3.0  1.0         NaN   2/6-2/11
# 4       2009.0  9.0  4.0  2.0  2.0  2.0  4.0  2.0  3.0         NaN   1/24-2/1
# 5       2010.0  9.0  1.0  1.0  2.0  2.0  3.0  3.0  2.0         NaN  2/13-2/21
# 6       2011.0  6.0  3.0  3.0  3.0  3.0  2.0  4.0  2.0         NaN    2/2-2/7
# 7       2012.0  9.0  2.0  2.0  1.0  4.0  2.0  1.0  1.0         NaN  1/21-1/29
# 8       2013.0  9.0  1.0  4.0  1.0  1.0  4.0  4.0  1.0         NaN   2/9-2/17
# 9       2014.0  6.0  3.0  3.0  3.0  3.0  1.0  3.0  1.0         NaN   1/30-2/4
# 10      2015.0  6.0  3.0  3.0  3.0  3.0  4.0  4.0  3.0         NaN  2/18-2/23
# ...
